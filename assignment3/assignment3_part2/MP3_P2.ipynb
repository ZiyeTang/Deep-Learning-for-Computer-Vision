# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader
from torchvision import models

from src.resnet_yolo import resnet50
from yolo_loss import YoloLoss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Initialization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# YOLO network hyperparameters
B = 2  # number of bounding box predictions per cell
S = 14  # width/height of network output grid (larger than 7x7 from paper since we use a different network)

# %% [markdown]
# To implement Yolo we will rely on a pretrained classifier as the backbone for our detection network. PyTorch offers a variety of models which are pretrained on ImageNet in the [`torchvision.models`](https://pytorch.org/docs/stable/torchvision/models.html) package. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
load_network_path = None #'checkpoints/best_detector.pth' 
pretrained = True

# use to load a previously trained network
if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)
# Out:
# Load pre-trained model
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
learning_rate = 0.001
num_epochs = 80
batch_size = 24

# Yolo loss component coefficients (as given in Yolo v1 paper)
lambda_coord = 5
lambda_noobj = 0.5

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector. This is not typically a good practice, but we will make an exception in this case to be able to get reasonable detection results with a comparatively small object detection dataset.
#
# The train dataset loader also using a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = 'data/VOCdevkit_2007/VOC2007/JPEGImages/'
annotation_file_train = 'data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=2)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = 'data/VOCdevkit_2007/VOC2007test/JPEGImages/'
annotation_file_test = 'data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=2)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
data = train_dataset[0]

# %% [markdown]
# ## Set up training tools

# %%
criterion = YoloLoss(S, B, lambda_coord, lambda_noobj)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# ## Train detector

# %%
best_test_loss = np.inf
learning_rate = 1e-3
for epoch in range(num_epochs):
    net.train()
    
    # Update learning rate late in training
#     if epoch == 30 or epoch == 40:
    if epoch == 40 or epoch == 60:
        learning_rate /= 10.0

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate
    
    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))
    
    total_loss = collections.defaultdict(int)
    
    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()
        
        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()
        
        if i==0 or (i+1) % 50 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.3f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)
    
    # evaluate the network on the test data
    if (epoch + 1) % 5 == 0:
        test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
        print(epoch, test_aps)
    with torch.no_grad():
        test_loss = 0.0
        net.eval()
        for i, data in enumerate(test_loader):
            data = (item.to(device) for item in data)
            images, target_boxes, target_cls, has_object_map = data
            
            pred = net(images)
            loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
            test_loss += loss_dict['total_loss'].item()
        test_loss /= len(test_loader)
    
    if best_test_loss > test_loss:
        best_test_loss = test_loss
        print('Updating best test loss: %.5f' % best_test_loss)
        torch.save(net.state_dict(),'checkpoints/best_detector.pth')
    
    if (epoch+1) in [5, 10, 20, 30, 40]:
        torch.save(net.state_dict(),'checkpoints/detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(),'checkpoints/detector.pth')
# Out:
# Starting epoch 1 / 80
# Learning Rate for this epoch: 0.001
# Epoch [1/80], Iter [1/209], Loss: total=88.254, reg=1.183, containing_obj=0.263, no_obj=56.700, cls=30.108
# Epoch [1/80], Iter [50/209], Loss: total=25.455, reg=0.800, containing_obj=0.326, no_obj=12.451, cls=11.878
# Epoch [1/80], Iter [100/209], Loss: total=16.177, reg=0.636, containing_obj=0.416, no_obj=6.451, cls=8.674
# Epoch [1/80], Iter [150/209], Loss: total=12.611, reg=0.545, containing_obj=0.478, no_obj=4.405, cls=7.182
# Epoch [1/80], Iter [200/209], Loss: total=10.661, reg=0.484, containing_obj=0.515, no_obj=3.366, cls=6.295
# Updating best test loss: 4.18252
#
#
# Starting epoch 2 / 80
# Learning Rate for this epoch: 0.001
# Epoch [2/80], Iter [1/209], Loss: total=4.483, reg=0.215, containing_obj=0.722, no_obj=0.217, cls=3.330
# Epoch [2/80], Iter [50/209], Loss: total=4.198, reg=0.276, containing_obj=0.675, no_obj=0.200, cls=3.047
# Epoch [2/80], Iter [100/209], Loss: total=3.970, reg=0.260, containing_obj=0.678, no_obj=0.187, cls=2.844
# Epoch [2/80], Iter [150/209], Loss: total=3.869, reg=0.253, containing_obj=0.679, no_obj=0.177, cls=2.760
# Epoch [2/80], Iter [200/209], Loss: total=3.749, reg=0.247, containing_obj=0.689, no_obj=0.168, cls=2.646
# Updating best test loss: 3.06099
#
#
# Starting epoch 3 / 80
# Learning Rate for this epoch: 0.001
# Epoch [3/80], Iter [1/209], Loss: total=3.514, reg=0.285, containing_obj=0.752, no_obj=0.132, cls=2.344
# Epoch [3/80], Iter [50/209], Loss: total=2.954, reg=0.208, containing_obj=0.724, no_obj=0.128, cls=1.894
# Epoch [3/80], Iter [100/209], Loss: total=2.958, reg=0.223, containing_obj=0.727, no_obj=0.124, cls=1.884
# Epoch [3/80], Iter [150/209], Loss: total=2.925, reg=0.216, containing_obj=0.722, no_obj=0.120, cls=1.867
# Epoch [3/80], Iter [200/209], Loss: total=2.901, reg=0.214, containing_obj=0.730, no_obj=0.117, cls=1.839
# Updating best test loss: 2.61432
#
#
# Starting epoch 4 / 80
# Learning Rate for this epoch: 0.001
# Epoch [4/80], Iter [1/209], Loss: total=2.293, reg=0.246, containing_obj=0.711, no_obj=0.104, cls=1.232
# Epoch [4/80], Iter [50/209], Loss: total=2.534, reg=0.199, containing_obj=0.769, no_obj=0.102, cls=1.464
# Epoch [4/80], Iter [100/209], Loss: total=2.504, reg=0.194, containing_obj=0.767, no_obj=0.101, cls=1.443
# Epoch [4/80], Iter [150/209], Loss: total=2.484, reg=0.197, containing_obj=0.756, no_obj=0.099, cls=1.432
# Epoch [4/80], Iter [200/209], Loss: total=2.441, reg=0.193, containing_obj=0.752, no_obj=0.098, cls=1.399
# Updating best test loss: 2.45358
#
#
# Starting epoch 5 / 80
# Learning Rate for this epoch: 0.001
# Epoch [5/80], Iter [1/209], Loss: total=1.840, reg=0.131, containing_obj=0.610, no_obj=0.093, cls=1.006
# Epoch [5/80], Iter [50/209], Loss: total=2.255, reg=0.179, containing_obj=0.760, no_obj=0.092, cls=1.223
# Epoch [5/80], Iter [100/209], Loss: total=2.241, reg=0.183, containing_obj=0.765, no_obj=0.091, cls=1.202
# Epoch [5/80], Iter [150/209], Loss: total=2.209, reg=0.180, containing_obj=0.764, no_obj=0.091, cls=1.173
# Epoch [5/80], Iter [200/209], Loss: total=2.210, reg=0.179, containing_obj=0.766, no_obj=0.091, cls=1.174
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:07<00:00, 26.38it/s]
# ---class aeroplane ap 0.006079488423463114---
# ---class bicycle ap 0.1040027939703936---
# ---class bird ap 0.013953643301630497---
# ---class boat ap 0.0---
# ---class bottle ap 0.003768528667127687---
# ---class bus ap 0.0--- (no predictions for this class)
# ---class car ap 0.014176276841338598---
# ---class cat ap 0.0---
# ---class chair ap 0.017807435057494148---
# ---class cow ap 0.025364594766017486---
# ---class diningtable ap 0.0--- (no predictions for this class)
# ---class dog ap 0.011792934745722157---
# ---class horse ap 0.1742016796488995---
# ---class motorbike ap 0.04506712150310078---
# ---class person ap 0.03073499232140707---
# ---class pottedplant ap 0.0006944444444444444---
# ---class sheep ap 0.028596025593374562---
# ---class sofa ap 0.0--- (no predictions for this class)
# ---class train ap 0.0--- (no predictions for this class)
# ---class tvmonitor ap 0.027160818573212703---
# ---map 0.025170038892881313---
# 4 [0.006079488423463114, 0.1040027939703936, 0.013953643301630497, 0.0, 0.003768528667127687, 0.0, 0.014176276841338598, 0.0, 0.017807435057494148, 0.025364594766017486, 0.0, 0.011792934745722157, 0.1742016796488995, 0.04506712150310078, 0.03073499232140707, 0.0006944444444444444, 0.028596025593374562, 0.0, 0.0, 0.027160818573212703]
# Updating best test loss: 2.23123
#
#
# Starting epoch 6 / 80
# Learning Rate for this epoch: 0.001
# Epoch [6/80], Iter [1/209], Loss: total=1.647, reg=0.186, containing_obj=0.709, no_obj=0.092, cls=0.661
# Epoch [6/80], Iter [50/209], Loss: total=1.957, reg=0.171, containing_obj=0.752, no_obj=0.091, cls=0.943
# Epoch [6/80], Iter [100/209], Loss: total=1.999, reg=0.165, containing_obj=0.762, no_obj=0.091, cls=0.980
# Epoch [6/80], Iter [150/209], Loss: total=2.030, reg=0.169, containing_obj=0.762, no_obj=0.092, cls=1.007
# Epoch [6/80], Iter [200/209], Loss: total=2.032, reg=0.169, containing_obj=0.760, no_obj=0.092, cls=1.011
# Updating best test loss: 2.13142
#
#
# Starting epoch 7 / 80
# Learning Rate for this epoch: 0.001
# Epoch [7/80], Iter [1/209], Loss: total=2.195, reg=0.241, containing_obj=0.616, no_obj=0.090, cls=1.249
# Epoch [7/80], Iter [50/209], Loss: total=1.819, reg=0.164, containing_obj=0.735, no_obj=0.092, cls=0.827
# Epoch [7/80], Iter [100/209], Loss: total=1.870, reg=0.162, containing_obj=0.753, no_obj=0.093, cls=0.862
# Epoch [7/80], Iter [150/209], Loss: total=1.891, reg=0.162, containing_obj=0.749, no_obj=0.095, cls=0.884
# Epoch [7/80], Iter [200/209], Loss: total=1.886, reg=0.163, containing_obj=0.755, no_obj=0.095, cls=0.874
#
#
# Starting epoch 8 / 80
# Learning Rate for this epoch: 0.001
# Epoch [8/80], Iter [1/209], Loss: total=2.188, reg=0.204, containing_obj=0.741, no_obj=0.093, cls=1.150
# Epoch [8/80], Iter [50/209], Loss: total=1.728, reg=0.153, containing_obj=0.741, no_obj=0.093, cls=0.741
# Epoch [8/80], Iter [100/209], Loss: total=1.732, reg=0.154, containing_obj=0.749, no_obj=0.093, cls=0.736
# Epoch [8/80], Iter [150/209], Loss: total=1.748, reg=0.155, containing_obj=0.752, no_obj=0.095, cls=0.747
# Epoch [8/80], Iter [200/209], Loss: total=1.768, reg=0.157, containing_obj=0.751, no_obj=0.096, cls=0.764
# Updating best test loss: 2.06774
#
#
# Starting epoch 9 / 80
# Learning Rate for this epoch: 0.001
# Epoch [9/80], Iter [1/209], Loss: total=1.907, reg=0.179, containing_obj=0.915, no_obj=0.093, cls=0.719
# Epoch [9/80], Iter [50/209], Loss: total=1.622, reg=0.146, containing_obj=0.723, no_obj=0.097, cls=0.655
# Epoch [9/80], Iter [100/209], Loss: total=1.668, reg=0.150, containing_obj=0.749, no_obj=0.097, cls=0.672
# Epoch [9/80], Iter [150/209], Loss: total=1.681, reg=0.148, containing_obj=0.745, no_obj=0.098, cls=0.690
# Epoch [9/80], Iter [200/209], Loss: total=1.695, reg=0.149, containing_obj=0.748, no_obj=0.099, cls=0.699
# Updating best test loss: 1.95521
#
#
# Starting epoch 10 / 80
# Learning Rate for this epoch: 0.001
# Epoch [10/80], Iter [1/209], Loss: total=1.344, reg=0.103, containing_obj=0.814, no_obj=0.121, cls=0.307
# Epoch [10/80], Iter [50/209], Loss: total=1.621, reg=0.151, containing_obj=0.739, no_obj=0.103, cls=0.628
# Epoch [10/80], Iter [100/209], Loss: total=1.634, reg=0.145, containing_obj=0.741, no_obj=0.104, cls=0.645
# Epoch [10/80], Iter [150/209], Loss: total=1.651, reg=0.144, containing_obj=0.754, no_obj=0.103, cls=0.649
# Epoch [10/80], Iter [200/209], Loss: total=1.642, reg=0.147, containing_obj=0.747, no_obj=0.104, cls=0.644
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:10<00:00, 25.93it/s]
# ---class aeroplane ap 0.10144167158616627---
# ---class bicycle ap 0.25573754347556343---
# ---class bird ap 0.07634089370823602---
# ---class boat ap 0.0029477716795990113---
# ---class bottle ap 0.03288471174989746---
# ---class bus ap 0.003129890453834116---
# ---class car ap 0.22547273871207119---
# ---class cat ap 0.2339685362152451---
# ---class chair ap 0.09201338555090152---
# ---class cow ap 0.12254369794700352---
# ---class diningtable ap 0.0---
# ---class dog ap 0.1689408123965371---
# ---class horse ap 0.2450483212862876---
# ---class motorbike ap 0.1887190937043816---
# ---class person ap 0.25676620712394105---
# ---class pottedplant ap 0.023400979866248818---
# ---class sheep ap 0.12906506792765723---
# ---class sofa ap 0.07950384484975066---
# ---class train ap 0.10043992145422125---
# ---class tvmonitor ap 0.1900959509327914---
# ---map 0.12642305203101672---
# 9 [0.10144167158616627, 0.25573754347556343, 0.07634089370823602, 0.0029477716795990113, 0.03288471174989746, 0.003129890453834116, 0.22547273871207119, 0.2339685362152451, 0.09201338555090152, 0.12254369794700352, 0.0, 0.1689408123965371, 0.2450483212862876, 0.1887190937043816, 0.25676620712394105, 0.023400979866248818, 0.12906506792765723, 0.07950384484975066, 0.10043992145422125, 0.1900959509327914]
#
#
# Starting epoch 11 / 80
# Learning Rate for this epoch: 0.001
# Epoch [11/80], Iter [1/209], Loss: total=1.546, reg=0.110, containing_obj=0.792, no_obj=0.103, cls=0.540
# Epoch [11/80], Iter [50/209], Loss: total=1.602, reg=0.146, containing_obj=0.755, no_obj=0.103, cls=0.599
# Epoch [11/80], Iter [100/209], Loss: total=1.605, reg=0.138, containing_obj=0.749, no_obj=0.104, cls=0.614
# Epoch [11/80], Iter [150/209], Loss: total=1.614, reg=0.143, containing_obj=0.746, no_obj=0.105, cls=0.621
# Epoch [11/80], Iter [200/209], Loss: total=1.615, reg=0.143, containing_obj=0.746, no_obj=0.105, cls=0.620
#
#
# Starting epoch 12 / 80
# Learning Rate for this epoch: 0.001
# Epoch [12/80], Iter [1/209], Loss: total=1.302, reg=0.085, containing_obj=0.631, no_obj=0.110, cls=0.476
# Epoch [12/80], Iter [50/209], Loss: total=1.469, reg=0.139, containing_obj=0.709, no_obj=0.110, cls=0.511
# Epoch [12/80], Iter [100/209], Loss: total=1.528, reg=0.142, containing_obj=0.735, no_obj=0.110, cls=0.541
# Epoch [12/80], Iter [150/209], Loss: total=1.512, reg=0.143, containing_obj=0.736, no_obj=0.112, cls=0.521
# Epoch [12/80], Iter [200/209], Loss: total=1.507, reg=0.139, containing_obj=0.738, no_obj=0.111, cls=0.519
# Updating best test loss: 1.93051
#
#
# Starting epoch 13 / 80
# Learning Rate for this epoch: 0.001
# Epoch [13/80], Iter [1/209], Loss: total=1.568, reg=0.114, containing_obj=0.677, no_obj=0.111, cls=0.666
# Epoch [13/80], Iter [50/209], Loss: total=1.461, reg=0.137, containing_obj=0.746, no_obj=0.112, cls=0.466
# Epoch [13/80], Iter [100/209], Loss: total=1.476, reg=0.137, containing_obj=0.743, no_obj=0.113, cls=0.482
# Epoch [13/80], Iter [150/209], Loss: total=1.499, reg=0.139, containing_obj=0.739, no_obj=0.113, cls=0.507
# Epoch [13/80], Iter [200/209], Loss: total=1.481, reg=0.136, containing_obj=0.735, no_obj=0.114, cls=0.496
#
#
# Starting epoch 14 / 80
# Learning Rate for this epoch: 0.001
# Epoch [14/80], Iter [1/209], Loss: total=1.517, reg=0.103, containing_obj=0.754, no_obj=0.111, cls=0.549
# Epoch [14/80], Iter [50/209], Loss: total=1.463, reg=0.133, containing_obj=0.718, no_obj=0.116, cls=0.496
# Epoch [14/80], Iter [100/209], Loss: total=1.454, reg=0.134, containing_obj=0.719, no_obj=0.115, cls=0.486
# Epoch [14/80], Iter [150/209], Loss: total=1.458, reg=0.134, containing_obj=0.723, no_obj=0.115, cls=0.486
# Epoch [14/80], Iter [200/209], Loss: total=1.468, reg=0.132, containing_obj=0.730, no_obj=0.115, cls=0.492
# Updating best test loss: 1.90164
#
#
# Starting epoch 15 / 80
# Learning Rate for this epoch: 0.001
# Epoch [15/80], Iter [1/209], Loss: total=1.148, reg=0.105, containing_obj=0.769, no_obj=0.109, cls=0.165
# Epoch [15/80], Iter [50/209], Loss: total=1.454, reg=0.128, containing_obj=0.764, no_obj=0.113, cls=0.449
# Epoch [15/80], Iter [100/209], Loss: total=1.443, reg=0.128, containing_obj=0.745, no_obj=0.116, cls=0.455
# Epoch [15/80], Iter [150/209], Loss: total=1.425, reg=0.126, containing_obj=0.741, no_obj=0.117, cls=0.441
# Epoch [15/80], Iter [200/209], Loss: total=1.413, reg=0.127, containing_obj=0.731, no_obj=0.117, cls=0.439
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:16<00:00, 25.23it/s]
# ---class aeroplane ap 0.23514873878178505---
# ---class bicycle ap 0.2862461180083207---
# ---class bird ap 0.1418252240793223---
# ---class boat ap 0.02070917623638846---
# ---class bottle ap 0.03274149789542715---
# ---class bus ap 0.19071672857858724---
# ---class car ap 0.42729000083590374---
# ---class cat ap 0.3299874459705342---
# ---class chair ap 0.15073442606611456---
# ---class cow ap 0.19997652315271836---
# ---class diningtable ap 0.0518940336901502---
# ---class dog ap 0.34803396816299864---
# ---class horse ap 0.5344107683812458---
# ---class motorbike ap 0.26339943415301725---
# ---class person ap 0.3078672434524079---
# ---class pottedplant ap 0.023708710185027806---
# ---class sheep ap 0.25369217438437325---
# ---class sofa ap 0.16841342412657884---
# ---class train ap 0.2980928415531602---
# ---class tvmonitor ap 0.2389657433188172---
# ---map 0.22519271105064392---
# 14 [0.23514873878178505, 0.2862461180083207, 0.1418252240793223, 0.02070917623638846, 0.03274149789542715, 0.19071672857858724, 0.42729000083590374, 0.3299874459705342, 0.15073442606611456, 0.19997652315271836, 0.0518940336901502, 0.34803396816299864, 0.5344107683812458, 0.26339943415301725, 0.3078672434524079, 0.023708710185027806, 0.25369217438437325, 0.16841342412657884, 0.2980928415531602, 0.2389657433188172]
#
#
# Starting epoch 16 / 80
# Learning Rate for this epoch: 0.001
# Epoch [16/80], Iter [1/209], Loss: total=1.245, reg=0.174, containing_obj=0.706, no_obj=0.127, cls=0.237
# Epoch [16/80], Iter [50/209], Loss: total=1.376, reg=0.127, containing_obj=0.721, no_obj=0.117, cls=0.411
# Epoch [16/80], Iter [100/209], Loss: total=1.375, reg=0.129, containing_obj=0.720, no_obj=0.117, cls=0.408
# Epoch [16/80], Iter [150/209], Loss: total=1.382, reg=0.128, containing_obj=0.713, no_obj=0.119, cls=0.422
# Epoch [16/80], Iter [200/209], Loss: total=1.385, reg=0.129, containing_obj=0.718, no_obj=0.121, cls=0.417
# Updating best test loss: 1.89990
#
#
# Starting epoch 17 / 80
# Learning Rate for this epoch: 0.001
# Epoch [17/80], Iter [1/209], Loss: total=0.813, reg=0.129, containing_obj=0.417, no_obj=0.132, cls=0.135
# Epoch [17/80], Iter [50/209], Loss: total=1.251, reg=0.115, containing_obj=0.695, no_obj=0.122, cls=0.319
# Epoch [17/80], Iter [100/209], Loss: total=1.306, reg=0.119, containing_obj=0.718, no_obj=0.122, cls=0.346
# Epoch [17/80], Iter [150/209], Loss: total=1.349, reg=0.122, containing_obj=0.720, no_obj=0.123, cls=0.384
# Epoch [17/80], Iter [200/209], Loss: total=1.358, reg=0.125, containing_obj=0.718, no_obj=0.123, cls=0.393
# Updating best test loss: 1.85991
#
#
# Starting epoch 18 / 80
# Learning Rate for this epoch: 0.001
# Epoch [18/80], Iter [1/209], Loss: total=1.774, reg=0.160, containing_obj=0.843, no_obj=0.121, cls=0.649
# Epoch [18/80], Iter [50/209], Loss: total=1.356, reg=0.128, containing_obj=0.723, no_obj=0.124, cls=0.379
# Epoch [18/80], Iter [100/209], Loss: total=1.365, reg=0.126, containing_obj=0.718, no_obj=0.125, cls=0.395
# Epoch [18/80], Iter [150/209], Loss: total=1.380, reg=0.129, containing_obj=0.721, no_obj=0.125, cls=0.405
# Epoch [18/80], Iter [200/209], Loss: total=1.363, reg=0.128, containing_obj=0.714, no_obj=0.125, cls=0.396
#
#
# Starting epoch 19 / 80
# Learning Rate for this epoch: 0.001
# Epoch [19/80], Iter [1/209], Loss: total=1.475, reg=0.111, containing_obj=0.664, no_obj=0.121, cls=0.579
# Epoch [19/80], Iter [50/209], Loss: total=1.301, reg=0.133, containing_obj=0.702, no_obj=0.123, cls=0.342
# Epoch [19/80], Iter [100/209], Loss: total=1.344, reg=0.127, containing_obj=0.734, no_obj=0.122, cls=0.362
# Epoch [19/80], Iter [150/209], Loss: total=1.327, reg=0.121, containing_obj=0.716, no_obj=0.124, cls=0.366
# Epoch [19/80], Iter [200/209], Loss: total=1.326, reg=0.120, containing_obj=0.717, no_obj=0.125, cls=0.365
#
#
# Starting epoch 20 / 80
# Learning Rate for this epoch: 0.001
# Epoch [20/80], Iter [1/209], Loss: total=1.203, reg=0.088, containing_obj=0.671, no_obj=0.144, cls=0.300
# Epoch [20/80], Iter [50/209], Loss: total=1.280, reg=0.108, containing_obj=0.711, no_obj=0.127, cls=0.334
# Epoch [20/80], Iter [100/209], Loss: total=1.298, reg=0.118, containing_obj=0.718, no_obj=0.128, cls=0.334
# Epoch [20/80], Iter [150/209], Loss: total=1.305, reg=0.119, containing_obj=0.713, no_obj=0.130, cls=0.343
# Epoch [20/80], Iter [200/209], Loss: total=1.295, reg=0.118, containing_obj=0.711, no_obj=0.130, cls=0.335
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:18<00:00, 24.94it/s]
# ---class aeroplane ap 0.28924427010990184---
# ---class bicycle ap 0.3502107394393532---
# ---class bird ap 0.3145794455034943---
# ---class boat ap 0.04988083077093134---
# ---class bottle ap 0.06590792256291089---
# ---class bus ap 0.3223188050608653---
# ---class car ap 0.5030986352208645---
# ---class cat ap 0.46339739814912295---
# ---class chair ap 0.1780347781148373---
# ---class cow ap 0.27253339460694537---
# ---class diningtable ap 0.15349547228287944---
# ---class dog ap 0.4415874402595742---
# ---class horse ap 0.5286951811404321---
# ---class motorbike ap 0.33153422356419426---
# ---class person ap 0.3839872822695771---
# ---class pottedplant ap 0.04307725995125053---
# ---class sheep ap 0.2607115035563529---
# ---class sofa ap 0.23475376348642807---
# ---class train ap 0.3423805835060669---
# ---class tvmonitor ap 0.2554245454767027---
# ---map 0.28924267375163426---
# 19 [0.28924427010990184, 0.3502107394393532, 0.3145794455034943, 0.04988083077093134, 0.06590792256291089, 0.3223188050608653, 0.5030986352208645, 0.46339739814912295, 0.1780347781148373, 0.27253339460694537, 0.15349547228287944, 0.4415874402595742, 0.5286951811404321, 0.33153422356419426, 0.3839872822695771, 0.04307725995125053, 0.2607115035563529, 0.23475376348642807, 0.3423805835060669, 0.2554245454767027]
#
#
# Starting epoch 21 / 80
# Learning Rate for this epoch: 0.001
# Epoch [21/80], Iter [1/209], Loss: total=1.160, reg=0.130, containing_obj=0.673, no_obj=0.138, cls=0.219
# Epoch [21/80], Iter [50/209], Loss: total=1.266, reg=0.112, containing_obj=0.719, no_obj=0.126, cls=0.309
# Epoch [21/80], Iter [100/209], Loss: total=1.264, reg=0.111, containing_obj=0.711, no_obj=0.132, cls=0.310
# Epoch [21/80], Iter [150/209], Loss: total=1.283, reg=0.117, containing_obj=0.714, no_obj=0.131, cls=0.321
# Epoch [21/80], Iter [200/209], Loss: total=1.282, reg=0.117, containing_obj=0.714, no_obj=0.131, cls=0.320
#
#
# Starting epoch 22 / 80
# Learning Rate for this epoch: 0.001
# Epoch [22/80], Iter [1/209], Loss: total=1.059, reg=0.151, containing_obj=0.628, no_obj=0.138, cls=0.143
# Epoch [22/80], Iter [50/209], Loss: total=1.226, reg=0.115, containing_obj=0.687, no_obj=0.134, cls=0.291
# Epoch [22/80], Iter [100/209], Loss: total=1.252, reg=0.113, containing_obj=0.694, no_obj=0.135, cls=0.310
# Epoch [22/80], Iter [150/209], Loss: total=1.266, reg=0.115, containing_obj=0.692, no_obj=0.135, cls=0.324
# Epoch [22/80], Iter [200/209], Loss: total=1.269, reg=0.116, containing_obj=0.703, no_obj=0.134, cls=0.316
# Updating best test loss: 1.84457
#
#
# Starting epoch 23 / 80
# Learning Rate for this epoch: 0.001
# Epoch [23/80], Iter [1/209], Loss: total=1.104, reg=0.073, containing_obj=0.581, no_obj=0.153, cls=0.297
# Epoch [23/80], Iter [50/209], Loss: total=1.269, reg=0.121, containing_obj=0.707, no_obj=0.133, cls=0.308
# Epoch [23/80], Iter [100/209], Loss: total=1.253, reg=0.121, containing_obj=0.699, no_obj=0.136, cls=0.297
# Epoch [23/80], Iter [150/209], Loss: total=1.238, reg=0.118, containing_obj=0.689, no_obj=0.136, cls=0.295
# Epoch [23/80], Iter [200/209], Loss: total=1.243, reg=0.118, containing_obj=0.691, no_obj=0.135, cls=0.299
# Updating best test loss: 1.80292
#
#
# Starting epoch 24 / 80
# Learning Rate for this epoch: 0.001
# Epoch [24/80], Iter [1/209], Loss: total=0.916, reg=0.082, containing_obj=0.638, no_obj=0.153, cls=0.044
# Epoch [24/80], Iter [50/209], Loss: total=1.240, reg=0.115, containing_obj=0.689, no_obj=0.139, cls=0.297
# Epoch [24/80], Iter [100/209], Loss: total=1.201, reg=0.110, containing_obj=0.666, no_obj=0.141, cls=0.284
# Epoch [24/80], Iter [150/209], Loss: total=1.232, reg=0.111, containing_obj=0.687, no_obj=0.139, cls=0.296
# Epoch [24/80], Iter [200/209], Loss: total=1.228, reg=0.111, containing_obj=0.682, no_obj=0.141, cls=0.295
#
#
# Starting epoch 25 / 80
# Learning Rate for this epoch: 0.001
# Epoch [25/80], Iter [1/209], Loss: total=1.316, reg=0.097, containing_obj=0.684, no_obj=0.120, cls=0.415
# Epoch [25/80], Iter [50/209], Loss: total=1.233, reg=0.107, containing_obj=0.683, no_obj=0.136, cls=0.307
# Epoch [25/80], Iter [100/209], Loss: total=1.233, reg=0.107, containing_obj=0.697, no_obj=0.136, cls=0.293
# Epoch [25/80], Iter [150/209], Loss: total=1.237, reg=0.104, containing_obj=0.701, no_obj=0.137, cls=0.294
# Epoch [25/80], Iter [200/209], Loss: total=1.240, reg=0.109, containing_obj=0.693, no_obj=0.138, cls=0.299
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:18<00:00, 24.95it/s]
# ---class aeroplane ap 0.38910262663155437---
# ---class bicycle ap 0.47344518183857087---
# ---class bird ap 0.2887725091057147---
# ---class boat ap 0.09229043154856119---
# ---class bottle ap 0.07301682479143613---
# ---class bus ap 0.3866068895885007---
# ---class car ap 0.5026150416779762---
# ---class cat ap 0.5297095913665821---
# ---class chair ap 0.1691204761065041---
# ---class cow ap 0.2953746477118045---
# ---class diningtable ap 0.15328270888340972---
# ---class dog ap 0.4938117004798229---
# ---class horse ap 0.5329522558271355---
# ---class motorbike ap 0.33795652614518795---
# ---class person ap 0.36809984376925065---
# ---class pottedplant ap 0.07603786897949484---
# ---class sheep ap 0.29961962761777067---
# ---class sofa ap 0.31842797647410737---
# ---class train ap 0.3946415404533564---
# ---class tvmonitor ap 0.3377895465974763---
# ---map 0.32563369077971094---
# 24 [0.38910262663155437, 0.47344518183857087, 0.2887725091057147, 0.09229043154856119, 0.07301682479143613, 0.3866068895885007, 0.5026150416779762, 0.5297095913665821, 0.1691204761065041, 0.2953746477118045, 0.15328270888340972, 0.4938117004798229, 0.5329522558271355, 0.33795652614518795, 0.36809984376925065, 0.07603786897949484, 0.29961962761777067, 0.31842797647410737, 0.3946415404533564, 0.3377895465974763]
#
#
# Starting epoch 26 / 80
# Learning Rate for this epoch: 0.001
# Epoch [26/80], Iter [1/209], Loss: total=1.147, reg=0.165, containing_obj=0.712, no_obj=0.157, cls=0.113
# Epoch [26/80], Iter [50/209], Loss: total=1.211, reg=0.109, containing_obj=0.701, no_obj=0.142, cls=0.258
# Epoch [26/80], Iter [100/209], Loss: total=1.234, reg=0.111, containing_obj=0.698, no_obj=0.145, cls=0.280
# Epoch [26/80], Iter [150/209], Loss: total=1.219, reg=0.108, containing_obj=0.692, no_obj=0.144, cls=0.276
# Epoch [26/80], Iter [200/209], Loss: total=1.220, reg=0.109, containing_obj=0.693, no_obj=0.142, cls=0.276
#
#
# Starting epoch 27 / 80
# Learning Rate for this epoch: 0.001
# Epoch [27/80], Iter [1/209], Loss: total=1.229, reg=0.085, containing_obj=0.764, no_obj=0.136, cls=0.244
# Epoch [27/80], Iter [50/209], Loss: total=1.174, reg=0.107, containing_obj=0.674, no_obj=0.142, cls=0.251
# Epoch [27/80], Iter [100/209], Loss: total=1.179, reg=0.106, containing_obj=0.669, no_obj=0.143, cls=0.262
# Epoch [27/80], Iter [150/209], Loss: total=1.183, reg=0.105, containing_obj=0.669, no_obj=0.143, cls=0.266
# Epoch [27/80], Iter [200/209], Loss: total=1.193, reg=0.106, containing_obj=0.682, no_obj=0.143, cls=0.262
#
#
# Starting epoch 28 / 80
# Learning Rate for this epoch: 0.001
# Epoch [28/80], Iter [1/209], Loss: total=1.210, reg=0.192, containing_obj=0.679, no_obj=0.127, cls=0.213
# Epoch [28/80], Iter [50/209], Loss: total=1.146, reg=0.100, containing_obj=0.686, no_obj=0.138, cls=0.222
# Epoch [28/80], Iter [100/209], Loss: total=1.165, reg=0.105, containing_obj=0.675, no_obj=0.142, cls=0.243
# Epoch [28/80], Iter [150/209], Loss: total=1.157, reg=0.103, containing_obj=0.671, no_obj=0.145, cls=0.239
# Epoch [28/80], Iter [200/209], Loss: total=1.160, reg=0.102, containing_obj=0.670, no_obj=0.146, cls=0.241
#
#
# Starting epoch 29 / 80
# Learning Rate for this epoch: 0.001
# Epoch [29/80], Iter [1/209], Loss: total=0.968, reg=0.204, containing_obj=0.507, no_obj=0.177, cls=0.080
# Epoch [29/80], Iter [50/209], Loss: total=1.187, reg=0.114, containing_obj=0.676, no_obj=0.149, cls=0.249
# Epoch [29/80], Iter [100/209], Loss: total=1.150, reg=0.103, containing_obj=0.661, no_obj=0.146, cls=0.240
# Epoch [29/80], Iter [150/209], Loss: total=1.157, reg=0.106, containing_obj=0.664, no_obj=0.147, cls=0.241
# Epoch [29/80], Iter [200/209], Loss: total=1.162, reg=0.105, containing_obj=0.668, no_obj=0.147, cls=0.242
#
#
# Starting epoch 30 / 80
# Learning Rate for this epoch: 0.001
# Epoch [30/80], Iter [1/209], Loss: total=1.311, reg=0.079, containing_obj=0.719, no_obj=0.168, cls=0.346
# Epoch [30/80], Iter [50/209], Loss: total=1.110, reg=0.098, containing_obj=0.670, no_obj=0.149, cls=0.193
# Epoch [30/80], Iter [100/209], Loss: total=1.139, reg=0.103, containing_obj=0.671, no_obj=0.148, cls=0.217
# Epoch [30/80], Iter [150/209], Loss: total=1.139, reg=0.102, containing_obj=0.666, no_obj=0.149, cls=0.221
# Epoch [30/80], Iter [200/209], Loss: total=1.147, reg=0.103, containing_obj=0.669, no_obj=0.148, cls=0.227
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:17<00:00, 25.07it/s]
# ---class aeroplane ap 0.4563412139548135---
# ---class bicycle ap 0.5287701330772065---
# ---class bird ap 0.3848807319731865---
# ---class boat ap 0.11452482473252515---
# ---class bottle ap 0.09304421027722651---
# ---class bus ap 0.43019200354278586---
# ---class car ap 0.5209637317702424---
# ---class cat ap 0.5707803777659823---
# ---class chair ap 0.20610481234032296---
# ---class cow ap 0.32949280646132384---
# ---class diningtable ap 0.19188625010417018---
# ---class dog ap 0.5077587152578568---
# ---class horse ap 0.5885228426435671---
# ---class motorbike ap 0.4741493562741754---
# ---class person ap 0.4185911304332329---
# ---class pottedplant ap 0.06007708043560195---
# ---class sheep ap 0.3480955627885395---
# ---class sofa ap 0.3410672158154273---
# ---class train ap 0.4698269464834717---
# ---class tvmonitor ap 0.38820868384496365---
# ---map 0.37116393149883103---
# 29 [0.4563412139548135, 0.5287701330772065, 0.3848807319731865, 0.11452482473252515, 0.09304421027722651, 0.43019200354278586, 0.5209637317702424, 0.5707803777659823, 0.20610481234032296, 0.32949280646132384, 0.19188625010417018, 0.5077587152578568, 0.5885228426435671, 0.4741493562741754, 0.4185911304332329, 0.06007708043560195, 0.3480955627885395, 0.3410672158154273, 0.4698269464834717, 0.38820868384496365]
#
#
# Starting epoch 31 / 80
# Learning Rate for this epoch: 0.001
# Epoch [31/80], Iter [1/209], Loss: total=1.219, reg=0.082, containing_obj=0.721, no_obj=0.142, cls=0.274
# Epoch [31/80], Iter [50/209], Loss: total=1.114, reg=0.097, containing_obj=0.645, no_obj=0.154, cls=0.217
# Epoch [31/80], Iter [100/209], Loss: total=1.135, reg=0.099, containing_obj=0.659, no_obj=0.155, cls=0.222
# Epoch [31/80], Iter [150/209], Loss: total=1.148, reg=0.102, containing_obj=0.667, no_obj=0.156, cls=0.223
# Epoch [31/80], Iter [200/209], Loss: total=1.148, reg=0.102, containing_obj=0.661, no_obj=0.155, cls=0.230
#
#
# Starting epoch 32 / 80
# Learning Rate for this epoch: 0.001
# Epoch [32/80], Iter [1/209], Loss: total=0.935, reg=0.071, containing_obj=0.633, no_obj=0.140, cls=0.091
# Epoch [32/80], Iter [50/209], Loss: total=1.155, reg=0.103, containing_obj=0.670, no_obj=0.148, cls=0.235
# Epoch [32/80], Iter [100/209], Loss: total=1.141, reg=0.103, containing_obj=0.665, no_obj=0.150, cls=0.223
# Epoch [32/80], Iter [150/209], Loss: total=1.150, reg=0.105, containing_obj=0.661, no_obj=0.152, cls=0.232
# Epoch [32/80], Iter [200/209], Loss: total=1.144, reg=0.102, containing_obj=0.659, no_obj=0.153, cls=0.230
# Updating best test loss: 1.78444
#
#
# Starting epoch 33 / 80
# Learning Rate for this epoch: 0.001
# Epoch [33/80], Iter [1/209], Loss: total=1.312, reg=0.077, containing_obj=0.816, no_obj=0.129, cls=0.290
# Epoch [33/80], Iter [50/209], Loss: total=1.125, reg=0.100, containing_obj=0.644, no_obj=0.152, cls=0.229
# Epoch [33/80], Iter [100/209], Loss: total=1.120, reg=0.099, containing_obj=0.651, no_obj=0.154, cls=0.216
# Epoch [33/80], Iter [150/209], Loss: total=1.121, reg=0.101, containing_obj=0.655, no_obj=0.154, cls=0.211
# Epoch [33/80], Iter [200/209], Loss: total=1.117, reg=0.102, containing_obj=0.648, no_obj=0.155, cls=0.213
# Updating best test loss: 1.78376
#
#
# Starting epoch 34 / 80
# Learning Rate for this epoch: 0.001
# Epoch [34/80], Iter [1/209], Loss: total=1.079, reg=0.119, containing_obj=0.666, no_obj=0.139, cls=0.155
# Epoch [34/80], Iter [50/209], Loss: total=1.132, reg=0.100, containing_obj=0.654, no_obj=0.153, cls=0.226
# Epoch [34/80], Iter [100/209], Loss: total=1.132, reg=0.098, containing_obj=0.654, no_obj=0.156, cls=0.224
# Epoch [34/80], Iter [150/209], Loss: total=1.128, reg=0.102, containing_obj=0.654, no_obj=0.156, cls=0.217
# Epoch [34/80], Iter [200/209], Loss: total=1.126, reg=0.102, containing_obj=0.652, no_obj=0.157, cls=0.215
# Updating best test loss: 1.77382
#
#
# Starting epoch 35 / 80
# Learning Rate for this epoch: 0.001
# Epoch [35/80], Iter [1/209], Loss: total=1.280, reg=0.099, containing_obj=0.773, no_obj=0.148, cls=0.261
# Epoch [35/80], Iter [50/209], Loss: total=1.141, reg=0.097, containing_obj=0.645, no_obj=0.159, cls=0.240
# Epoch [35/80], Iter [100/209], Loss: total=1.110, reg=0.094, containing_obj=0.650, no_obj=0.155, cls=0.211
# Epoch [35/80], Iter [150/209], Loss: total=1.103, reg=0.095, containing_obj=0.644, no_obj=0.156, cls=0.207
# Epoch [35/80], Iter [200/209], Loss: total=1.099, reg=0.095, containing_obj=0.640, no_obj=0.157, cls=0.206
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:18<00:00, 24.97it/s]
# ---class aeroplane ap 0.40695284641561824---
# ---class bicycle ap 0.55219387082924---
# ---class bird ap 0.3416169080140216---
# ---class boat ap 0.19116610705511838---
# ---class bottle ap 0.09673973964379255---
# ---class bus ap 0.48579622204055195---
# ---class car ap 0.5325254346869384---
# ---class cat ap 0.6191949750725525---
# ---class chair ap 0.24467598430440207---
# ---class cow ap 0.2884301337661206---
# ---class diningtable ap 0.2793066746971601---
# ---class dog ap 0.5423175024219161---
# ---class horse ap 0.6129176088754009---
# ---class motorbike ap 0.5002117322445788---
# ---class person ap 0.4160898738731793---
# ---class pottedplant ap 0.0903244081798509---
# ---class sheep ap 0.3418780158390441---
# ---class sofa ap 0.3867464126492975---
# ---class train ap 0.5353315425643149---
# ---class tvmonitor ap 0.39964115299534564---
# ---map 0.3932028573084222---
# 34 [0.40695284641561824, 0.55219387082924, 0.3416169080140216, 0.19116610705511838, 0.09673973964379255, 0.48579622204055195, 0.5325254346869384, 0.6191949750725525, 0.24467598430440207, 0.2884301337661206, 0.2793066746971601, 0.5423175024219161, 0.6129176088754009, 0.5002117322445788, 0.4160898738731793, 0.0903244081798509, 0.3418780158390441, 0.3867464126492975, 0.5353315425643149, 0.39964115299534564]
#
#
# Starting epoch 36 / 80
# Learning Rate for this epoch: 0.001
# Epoch [36/80], Iter [1/209], Loss: total=0.848, reg=0.050, containing_obj=0.574, no_obj=0.144, cls=0.080
# Epoch [36/80], Iter [50/209], Loss: total=1.102, reg=0.098, containing_obj=0.651, no_obj=0.157, cls=0.196
# Epoch [36/80], Iter [100/209], Loss: total=1.102, reg=0.097, containing_obj=0.643, no_obj=0.165, cls=0.197
# Epoch [36/80], Iter [150/209], Loss: total=1.098, reg=0.096, containing_obj=0.645, no_obj=0.162, cls=0.195
# Epoch [36/80], Iter [200/209], Loss: total=1.092, reg=0.096, containing_obj=0.642, no_obj=0.161, cls=0.192
#
#
# Starting epoch 37 / 80
# Learning Rate for this epoch: 0.001
# Epoch [37/80], Iter [1/209], Loss: total=1.443, reg=0.101, containing_obj=0.811, no_obj=0.155, cls=0.376
# Epoch [37/80], Iter [50/209], Loss: total=1.102, reg=0.105, containing_obj=0.619, no_obj=0.156, cls=0.223
# Epoch [37/80], Iter [100/209], Loss: total=1.098, reg=0.103, containing_obj=0.629, no_obj=0.157, cls=0.210
# Epoch [37/80], Iter [150/209], Loss: total=1.096, reg=0.100, containing_obj=0.634, no_obj=0.159, cls=0.204
# Epoch [37/80], Iter [200/209], Loss: total=1.100, reg=0.099, containing_obj=0.633, no_obj=0.160, cls=0.208
#
#
# Starting epoch 38 / 80
# Learning Rate for this epoch: 0.001
# Epoch [38/80], Iter [1/209], Loss: total=0.836, reg=0.057, containing_obj=0.514, no_obj=0.141, cls=0.125
# Epoch [38/80], Iter [50/209], Loss: total=1.052, reg=0.094, containing_obj=0.626, no_obj=0.158, cls=0.174
# Epoch [38/80], Iter [100/209], Loss: total=1.075, reg=0.098, containing_obj=0.622, no_obj=0.161, cls=0.193
# Epoch [38/80], Iter [150/209], Loss: total=1.077, reg=0.099, containing_obj=0.632, no_obj=0.160, cls=0.187
# Epoch [38/80], Iter [200/209], Loss: total=1.076, reg=0.097, containing_obj=0.631, no_obj=0.161, cls=0.187
#
#
# Starting epoch 39 / 80
# Learning Rate for this epoch: 0.001
# Epoch [39/80], Iter [1/209], Loss: total=0.716, reg=0.077, containing_obj=0.376, no_obj=0.211, cls=0.052
# Epoch [39/80], Iter [50/209], Loss: total=1.035, reg=0.094, containing_obj=0.611, no_obj=0.162, cls=0.169
# Epoch [39/80], Iter [100/209], Loss: total=1.065, reg=0.094, containing_obj=0.633, no_obj=0.163, cls=0.175
# Epoch [39/80], Iter [150/209], Loss: total=1.063, reg=0.093, containing_obj=0.627, no_obj=0.163, cls=0.180
# Epoch [39/80], Iter [200/209], Loss: total=1.059, reg=0.093, containing_obj=0.621, no_obj=0.163, cls=0.182
#
#
# Starting epoch 40 / 80
# Learning Rate for this epoch: 0.001
# Epoch [40/80], Iter [1/209], Loss: total=0.984, reg=0.133, containing_obj=0.574, no_obj=0.145, cls=0.132
# Epoch [40/80], Iter [50/209], Loss: total=1.043, reg=0.102, containing_obj=0.599, no_obj=0.157, cls=0.185
# Epoch [40/80], Iter [100/209], Loss: total=1.075, reg=0.099, containing_obj=0.610, no_obj=0.159, cls=0.207
# Epoch [40/80], Iter [150/209], Loss: total=1.069, reg=0.096, containing_obj=0.614, no_obj=0.161, cls=0.199
# Epoch [40/80], Iter [200/209], Loss: total=1.075, reg=0.097, containing_obj=0.621, no_obj=0.161, cls=0.196
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:21<00:00, 24.58it/s]
# ---class aeroplane ap 0.4353566772535886---
# ---class bicycle ap 0.5358831561269589---
# ---class bird ap 0.38437493340261353---
# ---class boat ap 0.20281666657122926---
# ---class bottle ap 0.05543308994794896---
# ---class bus ap 0.4866246005999765---
# ---class car ap 0.5682325446370509---
# ---class cat ap 0.5965779703326386---
# ---class chair ap 0.20852002578555---
# ---class cow ap 0.3627608699631538---
# ---class diningtable ap 0.350692004659219---
# ---class dog ap 0.5602860795161011---
# ---class horse ap 0.6542935201176815---
# ---class motorbike ap 0.5131494916301343---
# ---class person ap 0.4427920236331002---
# ---class pottedplant ap 0.07769936464808805---
# ---class sheep ap 0.3967020938769074---
# ---class sofa ap 0.42481382842183424---
# ---class train ap 0.5162181824899434---
# ---class tvmonitor ap 0.4072960134413989---
# ---map 0.4090261568527559---
# 39 [0.4353566772535886, 0.5358831561269589, 0.38437493340261353, 0.20281666657122926, 0.05543308994794896, 0.4866246005999765, 0.5682325446370509, 0.5965779703326386, 0.20852002578555, 0.3627608699631538, 0.350692004659219, 0.5602860795161011, 0.6542935201176815, 0.5131494916301343, 0.4427920236331002, 0.07769936464808805, 0.3967020938769074, 0.42481382842183424, 0.5162181824899434, 0.4072960134413989]
#
#
# Starting epoch 41 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [41/80], Iter [1/209], Loss: total=1.008, reg=0.089, containing_obj=0.526, no_obj=0.182, cls=0.210
# Epoch [41/80], Iter [50/209], Loss: total=1.079, reg=0.103, containing_obj=0.634, no_obj=0.159, cls=0.183
# Epoch [41/80], Iter [100/209], Loss: total=1.057, reg=0.101, containing_obj=0.611, no_obj=0.163, cls=0.182
# Epoch [41/80], Iter [150/209], Loss: total=1.046, reg=0.098, containing_obj=0.609, no_obj=0.164, cls=0.175
# Epoch [41/80], Iter [200/209], Loss: total=1.033, reg=0.095, containing_obj=0.607, no_obj=0.164, cls=0.167
# Updating best test loss: 1.76811
#
#
# Starting epoch 42 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [42/80], Iter [1/209], Loss: total=0.792, reg=0.132, containing_obj=0.382, no_obj=0.179, cls=0.098
# Epoch [42/80], Iter [50/209], Loss: total=1.008, reg=0.098, containing_obj=0.602, no_obj=0.168, cls=0.141
# Epoch [42/80], Iter [100/209], Loss: total=1.010, reg=0.099, containing_obj=0.594, no_obj=0.166, cls=0.151
# Epoch [42/80], Iter [150/209], Loss: total=1.035, reg=0.099, containing_obj=0.616, no_obj=0.161, cls=0.159
# Epoch [42/80], Iter [200/209], Loss: total=1.017, reg=0.097, containing_obj=0.606, no_obj=0.164, cls=0.150
# Updating best test loss: 1.74125
#
#
# Starting epoch 43 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [43/80], Iter [1/209], Loss: total=0.926, reg=0.098, containing_obj=0.612, no_obj=0.141, cls=0.075
# Epoch [43/80], Iter [50/209], Loss: total=0.958, reg=0.087, containing_obj=0.570, no_obj=0.166, cls=0.134
# Epoch [43/80], Iter [100/209], Loss: total=0.973, reg=0.089, containing_obj=0.578, no_obj=0.166, cls=0.140
# Epoch [43/80], Iter [150/209], Loss: total=0.975, reg=0.091, containing_obj=0.585, no_obj=0.166, cls=0.133
# Epoch [43/80], Iter [200/209], Loss: total=0.991, reg=0.091, containing_obj=0.595, no_obj=0.165, cls=0.139
#
#
# Starting epoch 44 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [44/80], Iter [1/209], Loss: total=1.035, reg=0.137, containing_obj=0.581, no_obj=0.169, cls=0.148
# Epoch [44/80], Iter [50/209], Loss: total=0.969, reg=0.090, containing_obj=0.579, no_obj=0.169, cls=0.131
# Epoch [44/80], Iter [100/209], Loss: total=0.995, reg=0.096, containing_obj=0.594, no_obj=0.168, cls=0.136
# Epoch [44/80], Iter [150/209], Loss: total=0.998, reg=0.093, containing_obj=0.597, no_obj=0.167, cls=0.141
# Epoch [44/80], Iter [200/209], Loss: total=1.001, reg=0.093, containing_obj=0.599, no_obj=0.168, cls=0.140
#
#
# Starting epoch 45 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [45/80], Iter [1/209], Loss: total=1.101, reg=0.066, containing_obj=0.681, no_obj=0.167, cls=0.186
# Epoch [45/80], Iter [50/209], Loss: total=1.065, reg=0.095, containing_obj=0.639, no_obj=0.159, cls=0.172
# Epoch [45/80], Iter [100/209], Loss: total=1.037, reg=0.093, containing_obj=0.623, no_obj=0.163, cls=0.158
# Epoch [45/80], Iter [150/209], Loss: total=1.023, reg=0.091, containing_obj=0.618, no_obj=0.163, cls=0.151
# Epoch [45/80], Iter [200/209], Loss: total=1.001, reg=0.090, containing_obj=0.602, no_obj=0.167, cls=0.142
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:19<00:00, 24.76it/s]
# ---class aeroplane ap 0.44618982318072076---
# ---class bicycle ap 0.5534178443045293---
# ---class bird ap 0.38828462595871494---
# ---class boat ap 0.22332227978891683---
# ---class bottle ap 0.09316174826283555---
# ---class bus ap 0.5270067261402269---
# ---class car ap 0.5812236106004397---
# ---class cat ap 0.6519903400504681---
# ---class chair ap 0.24312237008027612---
# ---class cow ap 0.36694124867959016---
# ---class diningtable ap 0.33646312636581366---
# ---class dog ap 0.5991731005887929---
# ---class horse ap 0.6779442997065477---
# ---class motorbike ap 0.48507263563771746---
# ---class person ap 0.46241244072193544---
# ---class pottedplant ap 0.09262312105403273---
# ---class sheep ap 0.38537472261113886---
# ---class sofa ap 0.39136781110468327---
# ---class train ap 0.5528927615403008---
# ---class tvmonitor ap 0.40770908294766584---
# ---map 0.4232846859662673---
# 44 [0.44618982318072076, 0.5534178443045293, 0.38828462595871494, 0.22332227978891683, 0.09316174826283555, 0.5270067261402269, 0.5812236106004397, 0.6519903400504681, 0.24312237008027612, 0.36694124867959016, 0.33646312636581366, 0.5991731005887929, 0.6779442997065477, 0.48507263563771746, 0.46241244072193544, 0.09262312105403273, 0.38537472261113886, 0.39136781110468327, 0.5528927615403008, 0.40770908294766584]
# Updating best test loss: 1.73355
#
#
# Starting epoch 46 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [46/80], Iter [1/209], Loss: total=0.784, reg=0.061, containing_obj=0.436, no_obj=0.225, cls=0.062
# Epoch [46/80], Iter [50/209], Loss: total=0.974, reg=0.094, containing_obj=0.590, no_obj=0.170, cls=0.121
# Epoch [46/80], Iter [100/209], Loss: total=1.007, reg=0.094, containing_obj=0.600, no_obj=0.168, cls=0.145
# Epoch [46/80], Iter [150/209], Loss: total=1.003, reg=0.097, containing_obj=0.598, no_obj=0.169, cls=0.139
# Epoch [46/80], Iter [200/209], Loss: total=0.998, reg=0.095, containing_obj=0.601, no_obj=0.169, cls=0.134
# Updating best test loss: 1.72521
#
#
# Starting epoch 47 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [47/80], Iter [1/209], Loss: total=0.750, reg=0.053, containing_obj=0.496, no_obj=0.180, cls=0.021
# Epoch [47/80], Iter [50/209], Loss: total=0.968, reg=0.092, containing_obj=0.570, no_obj=0.164, cls=0.141
# Epoch [47/80], Iter [100/209], Loss: total=1.009, reg=0.098, containing_obj=0.603, no_obj=0.163, cls=0.145
# Epoch [47/80], Iter [150/209], Loss: total=1.018, reg=0.096, containing_obj=0.609, no_obj=0.164, cls=0.149
# Epoch [47/80], Iter [200/209], Loss: total=1.000, reg=0.093, containing_obj=0.598, no_obj=0.166, cls=0.142
#
#
# Starting epoch 48 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [48/80], Iter [1/209], Loss: total=1.101, reg=0.089, containing_obj=0.698, no_obj=0.168, cls=0.146
# Epoch [48/80], Iter [50/209], Loss: total=0.993, reg=0.094, containing_obj=0.587, no_obj=0.166, cls=0.146
# Epoch [48/80], Iter [100/209], Loss: total=0.964, reg=0.091, containing_obj=0.570, no_obj=0.169, cls=0.134
# Epoch [48/80], Iter [150/209], Loss: total=0.962, reg=0.088, containing_obj=0.572, no_obj=0.168, cls=0.134
# Epoch [48/80], Iter [200/209], Loss: total=0.984, reg=0.089, containing_obj=0.592, no_obj=0.167, cls=0.137
#
#
# Starting epoch 49 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [49/80], Iter [1/209], Loss: total=1.405, reg=0.102, containing_obj=0.720, no_obj=0.219, cls=0.364
# Epoch [49/80], Iter [50/209], Loss: total=0.967, reg=0.094, containing_obj=0.583, no_obj=0.165, cls=0.125
# Epoch [49/80], Iter [100/209], Loss: total=0.982, reg=0.099, containing_obj=0.582, no_obj=0.165, cls=0.135
# Epoch [49/80], Iter [150/209], Loss: total=0.988, reg=0.093, containing_obj=0.588, no_obj=0.167, cls=0.140
# Epoch [49/80], Iter [200/209], Loss: total=0.985, reg=0.091, containing_obj=0.588, no_obj=0.167, cls=0.138
#
#
# Starting epoch 50 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [50/80], Iter [1/209], Loss: total=0.812, reg=0.079, containing_obj=0.478, no_obj=0.199, cls=0.056
# Epoch [50/80], Iter [50/209], Loss: total=0.948, reg=0.086, containing_obj=0.585, no_obj=0.165, cls=0.111
# Epoch [50/80], Iter [100/209], Loss: total=0.944, reg=0.092, containing_obj=0.576, no_obj=0.167, cls=0.108
# Epoch [50/80], Iter [150/209], Loss: total=0.966, reg=0.091, containing_obj=0.588, no_obj=0.167, cls=0.121
# Epoch [50/80], Iter [200/209], Loss: total=0.967, reg=0.090, containing_obj=0.585, no_obj=0.168, cls=0.124
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:19<00:00, 24.77it/s]
# ---class aeroplane ap 0.4456296007034151---
# ---class bicycle ap 0.5704972891168407---
# ---class bird ap 0.41871363491507596---
# ---class boat ap 0.20718757896666762---
# ---class bottle ap 0.1260384932600341---
# ---class bus ap 0.5155949526895913---
# ---class car ap 0.5898695714998031---
# ---class cat ap 0.6505058575296822---
# ---class chair ap 0.23982458378779214---
# ---class cow ap 0.35094180876442715---
# ---class diningtable ap 0.3213853435995394---
# ---class dog ap 0.6030470122763552---
# ---class horse ap 0.6647691458724962---
# ---class motorbike ap 0.4790318314251079---
# ---class person ap 0.4741197258229158---
# ---class pottedplant ap 0.09340266318905065---
# ---class sheep ap 0.389774778566764---
# ---class sofa ap 0.39468771689559673---
# ---class train ap 0.5657686673744609---
# ---class tvmonitor ap 0.4354978868515093---
# ---map 0.42681440715535635---
# 49 [0.4456296007034151, 0.5704972891168407, 0.41871363491507596, 0.20718757896666762, 0.1260384932600341, 0.5155949526895913, 0.5898695714998031, 0.6505058575296822, 0.23982458378779214, 0.35094180876442715, 0.3213853435995394, 0.6030470122763552, 0.6647691458724962, 0.4790318314251079, 0.4741197258229158, 0.09340266318905065, 0.389774778566764, 0.39468771689559673, 0.5657686673744609, 0.4354978868515093]
#
#
# Starting epoch 51 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [51/80], Iter [1/209], Loss: total=0.790, reg=0.061, containing_obj=0.498, no_obj=0.163, cls=0.068
# Epoch [51/80], Iter [50/209], Loss: total=0.979, reg=0.090, containing_obj=0.590, no_obj=0.169, cls=0.130
# Epoch [51/80], Iter [100/209], Loss: total=0.983, reg=0.090, containing_obj=0.593, no_obj=0.167, cls=0.133
# Epoch [51/80], Iter [150/209], Loss: total=0.971, reg=0.092, containing_obj=0.587, no_obj=0.168, cls=0.124
# Epoch [51/80], Iter [200/209], Loss: total=0.976, reg=0.092, containing_obj=0.589, no_obj=0.168, cls=0.126
#
#
# Starting epoch 52 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [52/80], Iter [1/209], Loss: total=0.919, reg=0.069, containing_obj=0.609, no_obj=0.141, cls=0.100
# Epoch [52/80], Iter [50/209], Loss: total=0.959, reg=0.092, containing_obj=0.579, no_obj=0.170, cls=0.118
# Epoch [52/80], Iter [100/209], Loss: total=0.975, reg=0.089, containing_obj=0.589, no_obj=0.169, cls=0.126
# Epoch [52/80], Iter [150/209], Loss: total=0.974, reg=0.089, containing_obj=0.588, no_obj=0.170, cls=0.128
# Epoch [52/80], Iter [200/209], Loss: total=0.973, reg=0.091, containing_obj=0.586, no_obj=0.169, cls=0.126
#
#
# Starting epoch 53 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [53/80], Iter [1/209], Loss: total=0.876, reg=0.060, containing_obj=0.508, no_obj=0.212, cls=0.097
# Epoch [53/80], Iter [50/209], Loss: total=0.977, reg=0.093, containing_obj=0.601, no_obj=0.173, cls=0.111
# Epoch [53/80], Iter [100/209], Loss: total=0.962, reg=0.089, containing_obj=0.589, no_obj=0.171, cls=0.112
# Epoch [53/80], Iter [150/209], Loss: total=0.968, reg=0.090, containing_obj=0.585, no_obj=0.173, cls=0.120
# Epoch [53/80], Iter [200/209], Loss: total=0.966, reg=0.089, containing_obj=0.586, no_obj=0.173, cls=0.118
#
#
# Starting epoch 54 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [54/80], Iter [1/209], Loss: total=0.813, reg=0.074, containing_obj=0.528, no_obj=0.187, cls=0.024
# Epoch [54/80], Iter [50/209], Loss: total=0.941, reg=0.084, containing_obj=0.568, no_obj=0.169, cls=0.119
# Epoch [54/80], Iter [100/209], Loss: total=0.965, reg=0.089, containing_obj=0.574, no_obj=0.170, cls=0.132
# Epoch [54/80], Iter [150/209], Loss: total=0.965, reg=0.089, containing_obj=0.569, no_obj=0.170, cls=0.137
# Epoch [54/80], Iter [200/209], Loss: total=0.965, reg=0.086, containing_obj=0.577, no_obj=0.170, cls=0.132
#
#
# Starting epoch 55 / 80
# Learning Rate for this epoch: 0.0001
# Epoch [55/80], Iter [1/209], Loss: total=0.905, reg=0.068, containing_obj=0.540, no_obj=0.199, cls=0.098
# Epoch [55/80], Iter [50/209], Loss: total=0.929, reg=0.084, containing_obj=0.572, no_obj=0.166, cls=0.107
# Epoch [55/80], Iter [100/209], Loss: total=0.936, reg=0.087, containing_obj=0.573, no_obj=0.165, cls=0.111
# Epoch [55/80], Iter [150/209], Loss: total=0.936, reg=0.084, containing_obj=0.567, no_obj=0.166, cls=0.120
# Epoch [55/80], Iter [200/209], Loss: total=0.954, reg=0.087, containing_obj=0.580, no_obj=0.166, cls=0.121
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:17<00:00, 25.12it/s]
# ---class aeroplane ap 0.4498049907774193---
# ---class bicycle ap 0.5799447443250096---
# ---class bird ap 0.4166437252005869---
# ---class boat ap 0.19660805760739175---
# ---class bottle ap 0.13730940283896365---
# ---class bus ap 0.5436331186074448---
# ---class car ap 0.5969536436124911---
# ---class cat ap 0.6451928074657638---
# ---class chair ap 0.24380166593533031---
# ...
# Epoch [63/80], Iter [150/209], Loss: total=0.958, reg=0.086, containing_obj=0.578, no_obj=0.172, cls=0.123
# Epoch [63/80], Iter [200/209], Loss: total=0.961, reg=0.086, containing_obj=0.581, no_obj=0.172, cls=0.122
#
#
# Starting epoch 64 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [64/80], Iter [1/209], Loss: total=1.330, reg=0.063, containing_obj=0.849, no_obj=0.153, cls=0.264
# Epoch [64/80], Iter [50/209], Loss: total=0.997, reg=0.083, containing_obj=0.608, no_obj=0.173, cls=0.133
# Epoch [64/80], Iter [100/209], Loss: total=0.978, reg=0.086, containing_obj=0.593, no_obj=0.176, cls=0.124
# Epoch [64/80], Iter [150/209], Loss: total=0.969, reg=0.088, containing_obj=0.587, no_obj=0.172, cls=0.122
# Epoch [64/80], Iter [200/209], Loss: total=0.963, reg=0.088, containing_obj=0.583, no_obj=0.173, cls=0.120
#
#
# Starting epoch 65 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [65/80], Iter [1/209], Loss: total=0.684, reg=0.041, containing_obj=0.452, no_obj=0.177, cls=0.014
# Epoch [65/80], Iter [50/209], Loss: total=0.962, reg=0.090, containing_obj=0.574, no_obj=0.171, cls=0.128
# Epoch [65/80], Iter [100/209], Loss: total=0.941, reg=0.089, containing_obj=0.561, no_obj=0.173, cls=0.118
# Epoch [65/80], Iter [150/209], Loss: total=0.944, reg=0.091, containing_obj=0.562, no_obj=0.173, cls=0.118
# Epoch [65/80], Iter [200/209], Loss: total=0.951, reg=0.090, containing_obj=0.573, no_obj=0.171, cls=0.117
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:17<00:00, 25.09it/s]
# ---class aeroplane ap 0.46781468630855183---
# ---class bicycle ap 0.6106835388845666---
# ---class bird ap 0.45026847541648474---
# ---class boat ap 0.2275897390709807---
# ---class bottle ap 0.13775208930204141---
# ---class bus ap 0.5444101033281314---
# ---class car ap 0.6008867321809401---
# ---class cat ap 0.6618970872526397---
# ---class chair ap 0.2577722733411888---
# ---class cow ap 0.3498346095883263---
# ---class diningtable ap 0.3038163308188382---
# ---class dog ap 0.6251144262646724---
# ---class horse ap 0.6758004936398314---
# ---class motorbike ap 0.5044325867226348---
# ---class person ap 0.4801882603574905---
# ---class pottedplant ap 0.09024867646296267---
# ---class sheep ap 0.3807392509498161---
# ---class sofa ap 0.4295572063065253---
# ---class train ap 0.5825683188939932---
# ---class tvmonitor ap 0.40524183331146024---
# ---map 0.4393308359201038---
# 64 [0.46781468630855183, 0.6106835388845666, 0.45026847541648474, 0.2275897390709807, 0.13775208930204141, 0.5444101033281314, 0.6008867321809401, 0.6618970872526397, 0.2577722733411888, 0.3498346095883263, 0.3038163308188382, 0.6251144262646724, 0.6758004936398314, 0.5044325867226348, 0.4801882603574905, 0.09024867646296267, 0.3807392509498161, 0.4295572063065253, 0.5825683188939932, 0.40524183331146024]
#
#
# Starting epoch 66 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [66/80], Iter [1/209], Loss: total=0.731, reg=0.092, containing_obj=0.429, no_obj=0.167, cls=0.044
# Epoch [66/80], Iter [50/209], Loss: total=0.959, reg=0.095, containing_obj=0.568, no_obj=0.175, cls=0.120
# Epoch [66/80], Iter [100/209], Loss: total=0.949, reg=0.092, containing_obj=0.570, no_obj=0.173, cls=0.113
# Epoch [66/80], Iter [150/209], Loss: total=0.954, reg=0.090, containing_obj=0.575, no_obj=0.171, cls=0.118
# Epoch [66/80], Iter [200/209], Loss: total=0.951, reg=0.089, containing_obj=0.576, no_obj=0.172, cls=0.114
#
#
# Starting epoch 67 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [67/80], Iter [1/209], Loss: total=1.196, reg=0.185, containing_obj=0.838, no_obj=0.131, cls=0.042
# Epoch [67/80], Iter [50/209], Loss: total=0.962, reg=0.086, containing_obj=0.592, no_obj=0.169, cls=0.115
# Epoch [67/80], Iter [100/209], Loss: total=0.943, reg=0.089, containing_obj=0.568, no_obj=0.169, cls=0.117
# Epoch [67/80], Iter [150/209], Loss: total=0.958, reg=0.088, containing_obj=0.575, no_obj=0.168, cls=0.127
# Epoch [67/80], Iter [200/209], Loss: total=0.955, reg=0.087, containing_obj=0.575, no_obj=0.168, cls=0.124
#
#
# Starting epoch 68 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [68/80], Iter [1/209], Loss: total=1.143, reg=0.055, containing_obj=0.594, no_obj=0.196, cls=0.298
# Epoch [68/80], Iter [50/209], Loss: total=0.950, reg=0.094, containing_obj=0.571, no_obj=0.168, cls=0.117
# Epoch [68/80], Iter [100/209], Loss: total=0.930, reg=0.090, containing_obj=0.563, no_obj=0.172, cls=0.104
# Epoch [68/80], Iter [150/209], Loss: total=0.943, reg=0.088, containing_obj=0.569, no_obj=0.171, cls=0.114
# Epoch [68/80], Iter [200/209], Loss: total=0.953, reg=0.089, containing_obj=0.576, no_obj=0.171, cls=0.116
#
#
# Starting epoch 69 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [69/80], Iter [1/209], Loss: total=0.942, reg=0.119, containing_obj=0.571, no_obj=0.146, cls=0.106
# Epoch [69/80], Iter [50/209], Loss: total=0.948, reg=0.085, containing_obj=0.578, no_obj=0.167, cls=0.118
# Epoch [69/80], Iter [100/209], Loss: total=0.937, reg=0.083, containing_obj=0.571, no_obj=0.170, cls=0.112
# Epoch [69/80], Iter [150/209], Loss: total=0.940, reg=0.085, containing_obj=0.569, no_obj=0.172, cls=0.114
# Epoch [69/80], Iter [200/209], Loss: total=0.949, reg=0.086, containing_obj=0.579, no_obj=0.170, cls=0.114
#
#
# Starting epoch 70 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [70/80], Iter [1/209], Loss: total=0.976, reg=0.073, containing_obj=0.609, no_obj=0.204, cls=0.090
# Epoch [70/80], Iter [50/209], Loss: total=0.962, reg=0.087, containing_obj=0.575, no_obj=0.171, cls=0.129
# Epoch [70/80], Iter [100/209], Loss: total=0.955, reg=0.091, containing_obj=0.570, no_obj=0.171, cls=0.123
# Epoch [70/80], Iter [150/209], Loss: total=0.962, reg=0.089, containing_obj=0.582, no_obj=0.171, cls=0.120
# Epoch [70/80], Iter [200/209], Loss: total=0.963, reg=0.088, containing_obj=0.579, no_obj=0.172, cls=0.125
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:19<00:00, 24.75it/s]
# ---class aeroplane ap 0.46823322376094223---
# ---class bicycle ap 0.590073223933109---
# ---class bird ap 0.4352070182020221---
# ---class boat ap 0.22090955588286595---
# ---class bottle ap 0.13551703575282162---
# ---class bus ap 0.5358994024680204---
# ---class car ap 0.6083714714762172---
# ---class cat ap 0.6659970784123193---
# ---class chair ap 0.2563655433056732---
# ---class cow ap 0.3801290173865261---
# ---class diningtable ap 0.3266173655161785---
# ---class dog ap 0.6239062123691627---
# ---class horse ap 0.681645734888469---
# ---class motorbike ap 0.4990210155707263---
# ---class person ap 0.4751825176120399---
# ---class pottedplant ap 0.10656047406862282---
# ---class sheep ap 0.3689535201432874---
# ---class sofa ap 0.4379315450978123---
# ---class train ap 0.5820414107335732---
# ---class tvmonitor ap 0.42572517618389494---
# ---map 0.44121437713821426---
# 69 [0.46823322376094223, 0.590073223933109, 0.4352070182020221, 0.22090955588286595, 0.13551703575282162, 0.5358994024680204, 0.6083714714762172, 0.6659970784123193, 0.2563655433056732, 0.3801290173865261, 0.3266173655161785, 0.6239062123691627, 0.681645734888469, 0.4990210155707263, 0.4751825176120399, 0.10656047406862282, 0.3689535201432874, 0.4379315450978123, 0.5820414107335732, 0.42572517618389494]
#
#
# Starting epoch 71 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [71/80], Iter [1/209], Loss: total=0.980, reg=0.121, containing_obj=0.681, no_obj=0.149, cls=0.029
# Epoch [71/80], Iter [50/209], Loss: total=0.931, reg=0.081, containing_obj=0.576, no_obj=0.173, cls=0.101
# Epoch [71/80], Iter [100/209], Loss: total=0.955, reg=0.083, containing_obj=0.575, no_obj=0.171, cls=0.126
# Epoch [71/80], Iter [150/209], Loss: total=0.950, reg=0.085, containing_obj=0.574, no_obj=0.171, cls=0.119
# Epoch [71/80], Iter [200/209], Loss: total=0.951, reg=0.086, containing_obj=0.576, no_obj=0.172, cls=0.117
#
#
# Starting epoch 72 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [72/80], Iter [1/209], Loss: total=1.488, reg=0.046, containing_obj=0.699, no_obj=0.192, cls=0.551
# Epoch [72/80], Iter [50/209], Loss: total=0.950, reg=0.090, containing_obj=0.567, no_obj=0.172, cls=0.121
# Epoch [72/80], Iter [100/209], Loss: total=0.952, reg=0.091, containing_obj=0.571, no_obj=0.171, cls=0.119
# Epoch [72/80], Iter [150/209], Loss: total=0.958, reg=0.089, containing_obj=0.576, no_obj=0.172, cls=0.122
# Epoch [72/80], Iter [200/209], Loss: total=0.957, reg=0.088, containing_obj=0.580, no_obj=0.173, cls=0.117
#
#
# Starting epoch 73 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [73/80], Iter [1/209], Loss: total=1.015, reg=0.094, containing_obj=0.587, no_obj=0.200, cls=0.134
# Epoch [73/80], Iter [50/209], Loss: total=0.946, reg=0.094, containing_obj=0.573, no_obj=0.170, cls=0.109
# Epoch [73/80], Iter [100/209], Loss: total=0.931, reg=0.089, containing_obj=0.562, no_obj=0.173, cls=0.107
# Epoch [73/80], Iter [150/209], Loss: total=0.936, reg=0.089, containing_obj=0.568, no_obj=0.174, cls=0.105
# Epoch [73/80], Iter [200/209], Loss: total=0.941, reg=0.091, containing_obj=0.572, no_obj=0.172, cls=0.106
#
#
# Starting epoch 74 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [74/80], Iter [1/209], Loss: total=0.817, reg=0.050, containing_obj=0.462, no_obj=0.218, cls=0.087
# Epoch [74/80], Iter [50/209], Loss: total=0.950, reg=0.087, containing_obj=0.590, no_obj=0.168, cls=0.106
# Epoch [74/80], Iter [100/209], Loss: total=0.933, reg=0.090, containing_obj=0.571, no_obj=0.172, cls=0.101
# Epoch [74/80], Iter [150/209], Loss: total=0.944, reg=0.088, containing_obj=0.577, no_obj=0.171, cls=0.108
# Epoch [74/80], Iter [200/209], Loss: total=0.941, reg=0.088, containing_obj=0.574, no_obj=0.171, cls=0.108
#
#
# Starting epoch 75 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [75/80], Iter [1/209], Loss: total=1.205, reg=0.224, containing_obj=0.583, no_obj=0.147, cls=0.251
# Epoch [75/80], Iter [50/209], Loss: total=0.948, reg=0.085, containing_obj=0.566, no_obj=0.173, cls=0.124
# Epoch [75/80], Iter [100/209], Loss: total=0.946, reg=0.085, containing_obj=0.565, no_obj=0.173, cls=0.123
# Epoch [75/80], Iter [150/209], Loss: total=0.947, reg=0.089, containing_obj=0.567, no_obj=0.172, cls=0.119
# Epoch [75/80], Iter [200/209], Loss: total=0.948, reg=0.089, containing_obj=0.569, no_obj=0.172, cls=0.118
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:18<00:00, 24.89it/s]
# ---class aeroplane ap 0.4731058150074581---
# ---class bicycle ap 0.5913052691425739---
# ---class bird ap 0.4607378884460267---
# ---class boat ap 0.22593858127769256---
# ---class bottle ap 0.15551711463883833---
# ---class bus ap 0.5596566393341696---
# ---class car ap 0.6062077495848633---
# ---class cat ap 0.6707625921301661---
# ---class chair ap 0.2559132526941651---
# ---class cow ap 0.36309714709226426---
# ---class diningtable ap 0.3263131123099378---
# ---class dog ap 0.6202543977844492---
# ---class horse ap 0.6889991806186333---
# ---class motorbike ap 0.4842202462024592---
# ---class person ap 0.4913728710872476---
# ---class pottedplant ap 0.10737616438640249---
# ---class sheep ap 0.3828176398785169---
# ---class sofa ap 0.41185801766726216---
# ---class train ap 0.6016999934377812---
# ---class tvmonitor ap 0.4207110437053778---
# ---map 0.4448932358213143---
# 74 [0.4731058150074581, 0.5913052691425739, 0.4607378884460267, 0.22593858127769256, 0.15551711463883833, 0.5596566393341696, 0.6062077495848633, 0.6707625921301661, 0.2559132526941651, 0.36309714709226426, 0.3263131123099378, 0.6202543977844492, 0.6889991806186333, 0.4842202462024592, 0.4913728710872476, 0.10737616438640249, 0.3828176398785169, 0.41185801766726216, 0.6016999934377812, 0.4207110437053778]
#
#
# Starting epoch 76 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [76/80], Iter [1/209], Loss: total=0.723, reg=0.135, containing_obj=0.383, no_obj=0.163, cls=0.043
# Epoch [76/80], Iter [50/209], Loss: total=0.903, reg=0.081, containing_obj=0.556, no_obj=0.179, cls=0.087
# Epoch [76/80], Iter [100/209], Loss: total=0.929, reg=0.085, containing_obj=0.564, no_obj=0.176, cls=0.104
# Epoch [76/80], Iter [150/209], Loss: total=0.955, reg=0.086, containing_obj=0.580, no_obj=0.174, cls=0.116
# Epoch [76/80], Iter [200/209], Loss: total=0.947, reg=0.087, containing_obj=0.574, no_obj=0.173, cls=0.113
#
#
# Starting epoch 77 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [77/80], Iter [1/209], Loss: total=0.742, reg=0.046, containing_obj=0.433, no_obj=0.142, cls=0.121
# Epoch [77/80], Iter [50/209], Loss: total=0.936, reg=0.091, containing_obj=0.557, no_obj=0.170, cls=0.118
# Epoch [77/80], Iter [100/209], Loss: total=0.952, reg=0.091, containing_obj=0.575, no_obj=0.173, cls=0.113
# Epoch [77/80], Iter [150/209], Loss: total=0.952, reg=0.087, containing_obj=0.575, no_obj=0.172, cls=0.119
# Epoch [77/80], Iter [200/209], Loss: total=0.947, reg=0.086, containing_obj=0.569, no_obj=0.173, cls=0.119
#
#
# Starting epoch 78 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [78/80], Iter [1/209], Loss: total=0.819, reg=0.058, containing_obj=0.474, no_obj=0.199, cls=0.088
# Epoch [78/80], Iter [50/209], Loss: total=0.927, reg=0.094, containing_obj=0.560, no_obj=0.166, cls=0.107
# Epoch [78/80], Iter [100/209], Loss: total=0.934, reg=0.087, containing_obj=0.570, no_obj=0.168, cls=0.109
# Epoch [78/80], Iter [150/209], Loss: total=0.945, reg=0.088, containing_obj=0.576, no_obj=0.168, cls=0.113
# Epoch [78/80], Iter [200/209], Loss: total=0.947, reg=0.087, containing_obj=0.575, no_obj=0.169, cls=0.115
#
#
# Starting epoch 79 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [79/80], Iter [1/209], Loss: total=1.131, reg=0.068, containing_obj=0.716, no_obj=0.150, cls=0.198
# Epoch [79/80], Iter [50/209], Loss: total=0.962, reg=0.091, containing_obj=0.576, no_obj=0.174, cls=0.122
# Epoch [79/80], Iter [100/209], Loss: total=0.951, reg=0.094, containing_obj=0.568, no_obj=0.170, cls=0.118
# Epoch [79/80], Iter [150/209], Loss: total=0.947, reg=0.091, containing_obj=0.569, no_obj=0.169, cls=0.119
# Epoch [79/80], Iter [200/209], Loss: total=0.946, reg=0.090, containing_obj=0.568, no_obj=0.170, cls=0.118
#
#
# Starting epoch 80 / 80
# Learning Rate for this epoch: 1e-05
# Epoch [80/80], Iter [1/209], Loss: total=0.869, reg=0.048, containing_obj=0.651, no_obj=0.160, cls=0.010
# Epoch [80/80], Iter [50/209], Loss: total=0.920, reg=0.080, containing_obj=0.546, no_obj=0.178, cls=0.116
# Epoch [80/80], Iter [100/209], Loss: total=0.937, reg=0.084, containing_obj=0.567, no_obj=0.175, cls=0.111
# Epoch [80/80], Iter [150/209], Loss: total=0.935, reg=0.086, containing_obj=0.567, no_obj=0.173, cls=0.109
# Epoch [80/80], Iter [200/209], Loss: total=0.941, reg=0.087, containing_obj=0.568, no_obj=0.171, cls=0.115
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:18<00:00, 24.95it/s]
# ---class aeroplane ap 0.4739105405641191---
# ---class bicycle ap 0.6120279274371889---
# ---class bird ap 0.46131867099464974---
# ---class boat ap 0.22806647069093572---
# ---class bottle ap 0.14853234778541252---
# ---class bus ap 0.5591243119353706---
# ---class car ap 0.6071337625385758---
# ---class cat ap 0.6649155737632944---
# ---class chair ap 0.25878622817626695---
# ---class cow ap 0.36350435344629556---
# ---class diningtable ap 0.3153140207608242---
# ---class dog ap 0.6162149824205778---
# ---class horse ap 0.6724415323876484---
# ---class motorbike ap 0.49513909068014983---
# ---class person ap 0.48185063110771975---
# ---class pottedplant ap 0.11476907163005895---
# ---class sheep ap 0.4090838056123091---
# ---class sofa ap 0.42750492228401005---
# ---class train ap 0.591536635737125---
# ---class tvmonitor ap 0.4285868323203048---
# ---map 0.44648808561364184---
# 79 [0.4739105405641191, 0.6120279274371889, 0.46131867099464974, 0.22806647069093572, 0.14853234778541252, 0.5591243119353706, 0.6071337625385758, 0.6649155737632944, 0.25878622817626695, 0.36350435344629556, 0.3153140207608242, 0.6162149824205778, 0.6724415323876484, 0.49513909068014983, 0.48185063110771975, 0.11476907163005895, 0.4090838056123091, 0.42750492228401005, 0.591536635737125, 0.4285868323203048]

# %% [markdown]
# # View example predictions

# %%
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"

# %%
net.eval()

# select random image from test set
image_name = random.choice(test_dataset.fnames)
image = cv2.imread(os.path.join(file_root_test, image_name))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print('predicting...')
result = predict_image(net, image_name, root_img_directory=file_root_test)
for left_up, right_bottom, class_name, _, prob in result:
    color = COLORS[VOC_CLASSES.index(class_name)]
    cv2.rectangle(image, left_up, right_bottom, color, 2)
    label = class_name + str(round(prob, 2))
    text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
    p1 = (left_up[0], left_up[1] - text_size[1])
    cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]),
                  color, -1)
    cv2.putText(image, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

plt.figure(figsize = (15,15))
plt.imshow(image)
# Out:
# predicting...

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:26<00:00, 23.99it/s]
# ---class aeroplane ap 0.4739105405641191---
# ---class bicycle ap 0.6120279274371889---
# ---class bird ap 0.46131867099464974---
# ---class boat ap 0.22806647069093572---
# ---class bottle ap 0.14853234778541252---
# ---class bus ap 0.5591243119353706---
# ---class car ap 0.6071337625385758---
# ---class cat ap 0.6649155737632944---
# ---class chair ap 0.25878622817626695---
# ---class cow ap 0.36350435344629556---
# ---class diningtable ap 0.3153140207608242---
# ---class dog ap 0.6162149824205778---
# ---class horse ap 0.6724415323876484---
# ---class motorbike ap 0.49513909068014983---
# ---class person ap 0.48185063110771975---
# ---class pottedplant ap 0.11476907163005895---
# ---class sheep ap 0.4090838056123091---
# ---class sofa ap 0.42750492228401005---
# ---class train ap 0.591536635737125---
# ---class tvmonitor ap 0.4285868323203048---
# ---map 0.44648808561364184---

# %% [markdown]
# ### Cell added to get intermediate mAP values for students

# %%
network_paths = ['checkpoints/detector_epoch_%d.pth' % epoch for epoch in [5, 10, 20, 30, 40]]+['detector.pth']
for load_network_path in network_paths:
    print('Loading saved network from {}'.format(load_network_path))
    net_loaded =  resnet50().to(device)
    net_loaded.load_state_dict(torch.load(load_network_path))
    evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# Loading saved network from checkpoints/detector_epoch_5.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:14<00:00, 25.40it/s]
# ---class aeroplane ap 0.006079488423463114---
# ---class bicycle ap 0.1040027939703936---
# ---class bird ap 0.013953643301630497---
# ---class boat ap 0.0---
# ---class bottle ap 0.003768528667127687---
# ---class bus ap 0.0--- (no predictions for this class)
# ---class car ap 0.014176276841338598---
# ---class cat ap 0.0---
# ---class chair ap 0.017807435057494148---
# ---class cow ap 0.025364594766017486---
# ---class diningtable ap 0.0--- (no predictions for this class)
# ---class dog ap 0.011792934745722157---
# ---class horse ap 0.1742016796488995---
# ---class motorbike ap 0.04506712150310078---
# ---class person ap 0.03073499232140707---
# ---class pottedplant ap 0.0006944444444444444---
# ---class sheep ap 0.028596025593374562---
# ---class sofa ap 0.0--- (no predictions for this class)
# ---class train ap 0.0--- (no predictions for this class)
# ---class tvmonitor ap 0.027160818573212703---
# ---map 0.025170038892881313---
# Loading saved network from checkpoints/detector_epoch_10.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:19<00:00, 24.78it/s]
# ---class aeroplane ap 0.10144167158616627---
# ---class bicycle ap 0.25573754347556343---
# ---class bird ap 0.07634089370823602---
# ---class boat ap 0.0029477716795990113---
# ---class bottle ap 0.03288471174989746---
# ---class bus ap 0.003129890453834116---
# ---class car ap 0.22547273871207119---
# ---class cat ap 0.2339685362152451---
# ---class chair ap 0.09201338555090152---
# ---class cow ap 0.12254369794700352---
# ---class diningtable ap 0.0---
# ---class dog ap 0.1689408123965371---
# ---class horse ap 0.2450483212862876---
# ---class motorbike ap 0.1887190937043816---
# ---class person ap 0.25676620712394105---
# ---class pottedplant ap 0.023400979866248818---
# ---class sheep ap 0.12906506792765723---
# ---class sofa ap 0.07950384484975066---
# ---class train ap 0.10043992145422125---
# ---class tvmonitor ap 0.1900959509327914---
# ---map 0.12642305203101672---
# Loading saved network from checkpoints/detector_epoch_20.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:25<00:00, 24.05it/s]
# ---class aeroplane ap 0.28924427010990184---
# ---class bicycle ap 0.3502107394393532---
# ---class bird ap 0.3145794455034943---
# ---class boat ap 0.04988083077093134---
# ---class bottle ap 0.06590792256291089---
# ---class bus ap 0.3223188050608653---
# ---class car ap 0.5030986352208645---
# ---class cat ap 0.46339739814912295---
# ---class chair ap 0.1780347781148373---
# ---class cow ap 0.27253339460694537---
# ---class diningtable ap 0.15349547228287944---
# ---class dog ap 0.4415874402595742---
# ---class horse ap 0.5286951811404321---
# ---class motorbike ap 0.33153422356419426---
# ---class person ap 0.3839872822695771---
# ---class pottedplant ap 0.04307725995125053---
# ---class sheep ap 0.2607115035563529---
# ---class sofa ap 0.23475376348642807---
# ---class train ap 0.3423805835060669---
# ---class tvmonitor ap 0.2554245454767027---
# ---map 0.28924267375163426---
# Loading saved network from checkpoints/detector_epoch_30.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:25<00:00, 24.13it/s]
# ---class aeroplane ap 0.4563412139548135---
# ---class bicycle ap 0.5287701330772065---
# ---class bird ap 0.3848807319731865---
# ---class boat ap 0.11452482473252515---
# ---class bottle ap 0.09304421027722651---
# ---class bus ap 0.43019200354278586---
# ---class car ap 0.5209637317702424---
# ---class cat ap 0.5707803777659823---
# ---class chair ap 0.20610481234032296---
# ---class cow ap 0.32949280646132384---
# ---class diningtable ap 0.19188625010417018---
# ---class dog ap 0.5077587152578568---
# ---class horse ap 0.5885228426435671---
# ---class motorbike ap 0.4741493562741754---
# ---class person ap 0.4185911304332329---
# ---class pottedplant ap 0.06007708043560195---
# ---class sheep ap 0.3480955627885395---
# ---class sofa ap 0.3410672158154273---
# ---class train ap 0.4698269464834717---
# ---class tvmonitor ap 0.38820868384496365---
# ---map 0.37116393149883103---
# Loading saved network from checkpoints/detector_epoch_40.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████████| 4950/4950 [03:27<00:00, 23.90it/s]
# ---class aeroplane ap 0.4353566772535886---
# ---class bicycle ap 0.5358831561269589---
# ---class bird ap 0.38437493340261353---
# ---class boat ap 0.20281666657122926---
# ---class bottle ap 0.05543308994794896---
# ---class bus ap 0.4866246005999765---
# ---class car ap 0.5682325446370509---
# ---class cat ap 0.5965779703326386---
# ---class chair ap 0.20852002578555---
# ---class cow ap 0.3627608699631538---
# ---class diningtable ap 0.350692004659219---
# ---class dog ap 0.5602860795161011---
# ---class horse ap 0.6542935201176815---
# ---class motorbike ap 0.5131494916301343---
# ---class person ap 0.4427920236331002---
# ---class pottedplant ap 0.07769936464808805---
# ---class sheep ap 0.3967020938769074---
# ---class sofa ap 0.42481382842183424---
# ---class train ap 0.5162181824899434---
# ---class tvmonitor ap 0.4072960134413989---
# ---map 0.4090261568527559---
# Loading saved network from detector.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       3 print('Loading saved network from {}'.format(load_network_path))
#       4 net_loaded =  resnet50().to(device)
# ----> 5 net_loaded.load_state_dict(torch.load(load_network_path))
#       6 evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\torch\serialization.py:771, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     768 if 'encoding' not in pickle_load_args.keys():
#     769     pickle_load_args['encoding'] = 'utf-8'
# --> 771 with _open_file_like(f, 'rb') as opened_file:
#     772     if _is_zipfile(opened_file):
#     773         # The zipfile reader is going to advance the current file position.
#     774         # If we want to actually tail call to torch.jit.load, we need to
#     775         # reset back to the original position.
#     776         orig_position = opened_file.tell()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\torch\serialization.py:270, in _open_file_like(name_or_buffer, mode)
#     268 def _open_file_like(name_or_buffer, mode):
#     269     if _is_path(name_or_buffer):
# --> 270         return _open_file(name_or_buffer, mode)
#     271     else:
#     272         if 'w' in mode:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\torch\serialization.py:251, in _open_file.__init__(self, name, mode)
#     250 def __init__(self, name, mode):
# --> 251     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'detector.pth'

# %%
output_submission_csv('my_new_solution.csv', test_aps)
